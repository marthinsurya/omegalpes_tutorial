# %% [markdown]
#  Bold: __string__ or **string** Italic: _string_ or *string*
#             ***asdada***
#     [section title](#section-title)
#         <font color=blue|red|green|pink|yellow>Text</font>
#         use - for creating bullet
#         <b> `This Tutorial`<br>
#             - [x] @mentions, #refs, [links](), **formatting**, and <del>tags</del> supported
# - [x] list syntax required (any unordered or ordered list supported)
# - [x] this is a complete item
# - [ ] this is an incomplete item
#
#     <br>
#     First Header | Second Header
# ------------ | -------------
# Content from cell 1 | Content from cell 2
# Content in the first column | Content in the second column
#     <br>
# | This | is   |
# |------|------|
# |   a  | table|

# %% [markdown]
# <font color=pink, size=20><b>OmegAlpes Tutorial</b></font><br>

# %% [markdown]
# # <font color=blue>Starting with OmegAlpes
#     This tutorial will guide you towards the mastery of OmegAlpes in simulating various scenarios. At the end of this tutor-ial, you will be able to integrate multiple constraints in your energy model for optimization purpose. Some notable con-straints that you will learn are:
#
#     - Cost constraints
#     - Storage integration
#     - Actors constraints
#     - Multiple energy model (heat and electricity)
#
#     Before we start, let's get familiar with the study case we are going to work on.
#
#     In this study case, we will try to solve John's problem with his energy problem. Currently, he is trying to reduce his  electricity bill by installing PV panel on top of his house. We, as his energy consultant, will utilize OmegAlpes capab-ilities to provide him advice on the best solution for his problem.
#
#     He described to us his home has several home appliances that are running in his home
#
# <img src="./image/electricity part.JPG"><br>
#
#     He also provived us his home electricity usage and pv production profile
#
# <img src="./image/johns cons prod.JPG" width="550" height="150" alt="Graph is produced using OmegAlpes">
# <br>
#
#     With this information, we will use OmegAlpes to simulate multiple scenarios and return to him with recommendations.
#     First, let's start of with simple simulation
#
# [Basic Tutorial] <a href="./omegalpes_tutorial1.ipynb">Tutorial 1</a><br><br>`
#
#
# <font color=pink>Learning outcome :<br>
# 1. Model an energy system with OmegAlpes<br>
# 2. General understanding of energy system components, such as energy units, time unit, export-import, input data, defining model objective<br>
# 3. Process optimization result<br>
#
#
# <font color=red> Comment : student will follow the tutorial, and at the end will be directed back to this page</font><br>
#
#
# <br>
# </b>

# %% [markdown]
# running this to confirm that you have finished 1st part

# %%
# %run quiz1
# Out:
# How much energy was imported from the grid?
# 3
# How much energy was consumed from the PV?
# 2
# How many energy units are there in the energy system?
# 1
# you got 1 / 3correct, you need to complete to progress further
#  Are you ready to redo again?
# How much energy was imported from the grid?
# 1
# How much energy was consumed from the PV?
# 2
# How many energy units are there in the energy system?
# 3
# you got 3 / 3correct, your key to further your journey %run quiz2

# %%
# %run text_input_quiz

# %% [markdown]
# <font color=red> upon finishing tutorial quiz 2, students will be given a code to continue the journey (the code : %run quiz2)</font><br><br>

# %%
# %run quiz2
# Out:
#  What path do you want to choose?
# RadioButtons(options=(('battery link with description', 1), ('grid price comparison link with description', 2)…
# Button(description='Proceed', style=ButtonStyle())
# Output()
# <a href='./tutorial 1.ipynb' target='_blank'> Click here to start simulating battery with Omegalpes</a>

# %% [markdown]
# <font color=red> Similar to previous section, students will be given a code to run quiz for each of the optimization choices again (similar to %run quiz1)</font><br><br>

# %% [markdown]
# 1. grid comparison<br>
# ![image.png](attachment:image.png)<br>
# Learning outcomes<br>
# Description <br>
#
# 2. storage <br>
# ![image.png](attachment:image.png)
#
# 3.
