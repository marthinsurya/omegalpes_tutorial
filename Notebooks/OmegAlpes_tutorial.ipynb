# %% [markdown]
# <font color=pink, size=20><b>OmegAlpes Tutorial</b></font><br>

# %% [markdown]
# # <font color=blue>Starting with OmegAlpes
#     This tutorial will guide you towards the mastery of OmegAlpes. At the end of this tutorial, you will be able to simulate various kind of scenarios depending on your need. Some scenarios you will learn in this tutorial:
#
#     - Cost constraints
#     - Storage integration
#     - Multiple energy model (heat and electricity)
#
#     Before we start, let's get familiar with the case study we are going to work on.
#
# [`[Study case]` Video](https://www.powtoon.com/embed/e3P9hvlJPb7/ "Click to watch the video!")
#
#
#      Let's get started with modelling his home !
#
#
# `[Tutorial 1]` <a href="./Notebooks/OmegAlpes_Tutorial_1.ipynb">Home Modelling</a><br><br>

# %% [markdown]
# # <font color=blue>Optimisation simulation
#
#     After finishing tutorial 1, you already cleared the first level of this tutorial. You already have the skill to create  simple simulation. Let us review your current skill and how you can levelling up in the next tutorials.
#
# <img src="./Resources/skill_tree.JPG" width="550" height="150" >
#
#     Let's watch video introduction of tutorial 2 for details.
#
# [`[Tutorial 2]` Video introduction](https://www.powtoon.com/embed/bIGBgirCHog/ "Click to watch the video!")
#
# `Current skills :`<br>
#     1. General understanding of the model components
#     You acquired the skill to make basic energy units. Level up your skill in Tutorial 2 to acquire the ability to add vari-ety of useful components, such as battery and shiftable load ! With these additions into the model, you can help John   save more energy.
#
# <img src="./Resources/tutorial2.JPG" width="550" height="150" >
#
#      To level up this skill :
# `[Tutorial 2 Level 2] :` <a href="./Notebooks/OmegAlpes_Tutorial_2.ipynb">Tutorial 2 - Battery and Shiftable consumption</a><br><br>
#
#     2. Model an energy system with OmegAlpes
#     You acquired the skill to model a simple energy system with electricity. Level up your skill in Tutorial 3 to acquire the ability to add thermal energy into your model. Let's see what will happen if John utilize his water heater to produce electricity !
#
# <img src="./Resources/4-heat.JPG" width="550" height="150" >
#
#     To level up this skill :
# `[Tutorial 3 Level 2] :`    <a href="./Notebooks/OmegAlpes_Tutorial_3.ipynb">Tutorial 3 - Heat and Electricity combined system</a><br><br>
#
#     3. Processing optimisation result
#     You acquired the skill to optimize result with one objective (minimize grid import). Level up your skill in Tutorial 3  to acquire the ability to add more objectives, such as minimize cost. You can combine two of these designs to find opti-mal solution!
#
# <img src="./Resources/3-combine.jpg" width="600" height="150" >
#
#
#      To level up this skill :
# `[Tutorial 4 Level 2] :`    <a href="./Notebooks/OmegAlpes_Tutorial_4.ipynb">Tutorial 4 - Cost comparison

# %% [markdown]
# # <font color=blue>Further Study

# %% [markdown]
#     There are a lot more capabilities of OmegAlpes that you can explore further. You can learn further by finishing this last challenge!

# %%
# %run ./Resources/quiz_tutorial50
